# %% [markdown]
# ### sum_digits_assert

# %%
# Note the assert statement activates when s is passed as ""
def sum_digits_assert(s):
    """ s is a non-empty string containing digits
    Returns sum of all characters that are digits """
    assert len(s) != 0, "s is empty"
    total = 0
    for char in s:
        try:
            val = int(char)
            total += val
        except:
            raise ValueError("string contained a character") 
    return total

# print(sum_digits_assert(""))
# print(sum_digits_assert("123"))
print(sum_digits_assert("123abc"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 1 line 9
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> try:
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a>     val = int(char)
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     total += val
#
# ValueError: invalid literal for int() with base 10: 'a'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a>     return total
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a> # print(sum_digits_assert(""))
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a> # print(sum_digits_assert("123"))
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a> print(sum_digits_assert("123abc"))
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 1 line 1
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>         total += val
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a>     except:
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>         raise ValueError("string contained a character")
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> return total
#
# ValueError: string contained a character

# %%
# Note the assert statement activates when s is passed as ""
def sum_digits_assert(s):
    """ s is a non-empty string containing digits
    Returns sum of all characters that are digits """
    assert len(s) != 0, "s is empty"
    total = 0
    for char in s:
        try:
            val = int(char)
            total += val
        except:
            raise ValueError("string contained a character") 
    return total

# print(sum_digits_assert(""))
print(sum_digits_assert("123"))
# print(sum_digits_assert("123abc"))
# Out:
# 6

# %%
# Note the assert statement activates when s is passed as ""
def sum_digits_assert(s):
    """ s is a non-empty string containing digits
    Returns sum of all characters that are digits """
    assert len(s) != 0, "s is empty"
    total = 0
    for char in s:
        try:
            val = int(char)
            total += val
        except:
            raise ValueError("string contained a character") 
    return total

print(sum_digits_assert(""))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a>             raise ValueError("string contained a character")
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     return total
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=14'>15</a> print(sum_digits_assert(""))
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 3 line 5
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> def sum_digits_assert(s):
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a>     """ s is a non-empty string containing digits
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a>     Returns sum of all characters that are digits """
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a>     assert len(s) != 0, "s is empty"
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     total = 0
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     for char in s:
#
# AssertionError: s is empty

# %% [markdown]
# ### ANSWERS TO AT HOME

# %%
##############################################
################### ANSWERS TO AT HOME ###################
################################################
def pairwise_div(Lnum, Ldenom):
    """ Lnum and Ldenom are non-empty lists of equal lengths
        containing numbers
    Returns a new list whose elements are the pairwise 
    division of an element in Lnum by an element in Ldenom. 
    Raise a ValueError if L2 contains 0 or if the code can't 
    perform the division for some reason. """
    assert (len(Lnum) == len(Ldenom)) and (len(Ldenom) != 0)
    L = []
    for i in range(len(Lnum)):
        try:
            L.append(Lnum[i]/Ldenom[i])
        except:
            raise ValueError
    return L

# %%
    
# For example:
L1 = [4,5,6]
L2 = [1,2,3]    
print(pairwise_div(L1, L2))  # prints [4.0,2.5,2.0]
# Out:
# [4.0, 2.5, 2.0]

# %%
L1 = [4,5,6]
L2 = [1,0,3]    
print(pairwise_div(L1, L2))  # raises a ValueError
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> try:
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>     L.append(Lnum[i]/Ldenom[i])
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> except:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> L1 = [4,5,6]
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> L2 = [1,0,3]
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> print(pairwise_div(L1, L2))  # raises a ValueError
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=14'>15</a>         L.append(Lnum[i]/Ldenom[i])
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a>     except:
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a>         raise ValueError
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W5sZmlsZQ%3D%3D?line=17'>18</a> return L
#
# ValueError:

# %%
L1 = []
L2 = [1,0,3]    
print(pairwise_div(L1, L2))  # raises a AssertionError
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> L1 = []
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> L2 = [1,0,3]
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> print(pairwise_div(L1, L2))  # raises a ValueError
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> def pairwise_div(Lnum, Ldenom):
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     """ Lnum and Ldenom are non-empty lists of equal lengths
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=5'>6</a>         containing numbers
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>     Returns a new list whose elements are the pairwise
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     division of an element in Lnum by an element in Ldenom.
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=8'>9</a>     Raise a ValueError if L2 contains 0 or if the code can't
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a>     perform the division for some reason. """
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a>     assert (len(Lnum) == len(Ldenom)) and (len(Ldenom) != 0)
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a>     L = []
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>     for i in range(len(Lnum)):
#
# AssertionError:

# %% [markdown]
# ##### Again

# %%
##############################################
################### ANSWERS TO AT HOME ###################
################################################
def pairwise_div(Lnum, Ldenom):
    """ Lnum and Ldenom are non-empty lists of equal lengths
        containing numbers
    Returns a new list whose elements are the pairwise 
    division of an element in Lnum by an element in Ldenom. 
    Raise a ValueError if L2 contains 0 or if the code can't 
    perform the division for some reason. """
    assert (len(Lnum) == len(Ldenom)) , 'lengths diff'
    assert len(Lnum) != 0 and len(Ldenom) != 0, 'empty list'

    L = []
    for i in range(len(Lnum)):
        try:
            L.append(Lnum[i]/Ldenom[i])
        except:
            raise ValueError
    return L

# %%
L1 = [6,7]
L2 = [1,0,3]    
print(pairwise_div(L1, L2))  # raises a AssertionError
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 12 line 3
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> L1 = [6,7]
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> L2 = [1,0,3]
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> print(pairwise_div(L1, L2))  # raises a AssertionError
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 12 line 1
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> def pairwise_div(Lnum, Ldenom):
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=4'>5</a>     """ Lnum and Ldenom are non-empty lists of equal lengths
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>         containing numbers
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>     Returns a new list whose elements are the pairwise
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=7'>8</a>     division of an element in Lnum by an element in Ldenom.
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=8'>9</a>     Raise a ValueError if L2 contains 0 or if the code can't
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a>     perform the division for some reason. """
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=10'>11</a>     assert (len(Lnum) == len(Ldenom)) , 'lengths diff'
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a>     assert (len(Ldenom) != 0), 'empty list'
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X10sZmlsZQ%3D%3D?line=13'>14</a>     L = []
#
# AssertionError: lengths diff

# %%
L1 = []
L2 = [1,0,3]    
print(pairwise_div(L1, L2))  # raises a AssertionError
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> L1 = []
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> L2 = [1,0,3]
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> print(pairwise_div(L1, L2))  # raises a AssertionError
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 13 line 1
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> def pairwise_div(Lnum, Ldenom):
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     """ Lnum and Ldenom are non-empty lists of equal lengths
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=5'>6</a>         containing numbers
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=6'>7</a>     Returns a new list whose elements are the pairwise
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=7'>8</a>     division of an element in Lnum by an element in Ldenom.
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a>     Raise a ValueError if L2 contains 0 or if the code can't
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a>     perform the division for some reason. """
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a>     assert (len(Lnum) == len(Ldenom)) , 'lengths diff'
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a>     assert len(Lnum) != 0 and len(Ldenom) != 0, 'empty list'
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X21sZmlsZQ%3D%3D?line=13'>14</a>     L = []
#
# AssertionError: lengths diff

# %% [markdown]
# #### test

# %%
##############################################
################### ANSWERS TO AT HOME ###################
################################################
def pairwise_div(Lnum, Ldenom):
    """ Lnum and Ldenom are non-empty lists of equal lengths
        containing numbers
    Returns a new list whose elements are the pairwise 
    division of an element in Lnum by an element in Ldenom. 
    Raise a ValueError if L2 contains 0 or if the code can't 
    perform the division for some reason. """
    assert len(Lnum) != 0 and len(Ldenom) != 0, 'empty list'
    assert (len(Lnum) == len(Ldenom)) , 'lengths diff'

    L = []
    for i in range(len(Lnum)):
        try:
            L.append(Lnum[i]/Ldenom[i])
        except:
            raise ValueError
    return L


L1 = []
L2 = [1,0,3]    
print(pairwise_div(L1, L2))  # raises a AssertionError
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=22'>23</a> L1 = []
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=23'>24</a> L2 = [1,0,3]
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=24'>25</a> print(pairwise_div(L1, L2))  # raises a AssertionError
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 15 line 1
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> def pairwise_div(Lnum, Ldenom):
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a>     """ Lnum and Ldenom are non-empty lists of equal lengths
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=5'>6</a>         containing numbers
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a>     Returns a new list whose elements are the pairwise
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a>     division of an element in Lnum by an element in Ldenom.
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=8'>9</a>     Raise a ValueError if L2 contains 0 or if the code can't
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=9'>10</a>     perform the division for some reason. """
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=10'>11</a>     assert len(Lnum) != 0 and len(Ldenom) != 0, 'empty list'
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a>     assert (len(Lnum) == len(Ldenom)) , 'lengths diff'
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a>     L = []
#
# AssertionError: empty list

# %% [markdown]
# ## Longer Example

# %%
#######################################
## EXAMPLE: Longer exceptions and lists example
#######################################
def get_stats(class_list, avg_func):
    """ class_list is a list of student info: 
            * name as a list
            * grades as a list
        avg_func is a function that takes in a list and returns a float
    """
    new_stats = []
    for person in class_list:
        new_stats.append([person[0], person[1], avg_func(person[1])])
    return new_stats 

test_grades = [[['peter', 'parker'], [10.0, 55.0, 85.0]], 
               [['bruce', 'wayne'], [10.0, 80.0, 75.0]],
               [['captain', 'america'], [80.0,10.0,96.0]],
               [['thor'], []]]

## Note in the get_stats function calls below, 
## we are passing the various avg1/2/3 function names as params
## to test different avg function behaviours with the same data

# avg function: version without an exception
def avg1(grades):
    return (sum(grades))/len(grades)

print(get_stats(test_grades, avg1))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 17 line 2
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=24'>25</a> def avg1(grades):
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=25'>26</a>     return (sum(grades))/len(grades)
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=27'>28</a> print(get_stats(test_grades, avg1))
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 17 line 1
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> new_stats = []
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a> for person in class_list:
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a>     new_stats.append([person[0], person[1], avg_func(person[1])])
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=12'>13</a> return new_stats
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 17 line 2
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=24'>25</a> def avg1(grades):
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X31sZmlsZQ%3D%3D?line=25'>26</a>     return (sum(grades))/len(grades)
#
# ZeroDivisionError: division by zero

# %%
 # avg function: version with an exception
def avg2(grades):
    try:
        return sum(grades)/len(grades)
    except ZeroDivisionError:
        print('warning: no grades data')


print(get_stats(test_grades, avg2))
# Out:
# warning: no grades data
# [[['peter', 'parker'], [10.0, 55.0, 85.0], 50.0], [['bruce', 'wayne'], [10.0, 80.0, 75.0], 55.0], [['captain', 'america'], [80.0, 10.0, 96.0], 62.0], [['thor'], [], None]]

# %%
# avg function: version with an exception
def avg3(grades):
    try:
        return sum(grades)/len(grades)
    except ZeroDivisionError:
        print('warning: no grades data')
        return 0.0 ## for [['thor'], [], None]]
    

print(get_stats(test_grades, avg3))
# Out:
# warning: no grades data
# [[['peter', 'parker'], [10.0, 55.0, 85.0], 50.0], [['bruce', 'wayne'], [10.0, 80.0, 75.0], 55.0], [['captain', 'america'], [80.0, 10.0, 96.0], 62.0], [['thor'], [], 0.0]]

# %%
# avg function: version with assert
def avg4(grades):
    assert len(grades) != 0, 'warning: no grades data'
    return sum(grades)/len(grades)


print(get_stats(test_grades, avg4))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 20 line 7
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a>     assert len(grades) != 0, 'warning: no grades data'
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a>     return sum(grades)/len(grades)
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=6'>7</a> print(get_stats(test_grades, avg4))
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 20 line 1
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=9'>10</a> new_stats = []
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=10'>11</a> for person in class_list:
# ---> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=11'>12</a>     new_stats.append([person[0], person[1], avg_func(person[1])])
#      <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=12'>13</a> return new_stats
#
# /Users/indrani.sarkar/Python Basics /Python Basics - August/31_8_MIT_12.ipynb Cell 20 line 3
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> def avg4(grades):
# ----> <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a>     assert len(grades) != 0, 'warning: no grades data'
#       <a href='vscode-notebook-cell:/Users/indrani.sarkar/Python%20Basics%20/Python%20Basics%20-%20August/31_8_MIT_12.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a>     return sum(grades)/len(grades)
#
# AssertionError: warning: no grades data

# %% [markdown]
# assert len(grades) != 0: This checks whether the grades list is not empty.
#
# If len(grades) != 0 (meaning the list is not empty), the program continues to execute as usual.
#
#
# If len(grades) == 0 (meaning the list is empty), the assertion fails.
# 'warning: no grades data': This is the message that gets displayed if the assertion fails (i.e., if the grades list is empty).
